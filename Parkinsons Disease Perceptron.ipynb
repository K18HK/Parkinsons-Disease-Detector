# %% [markdown]
# # Parkinson Disease Classification using Perceptron
# ### By roll nos. 1,37,42,49

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('parkinsons_disease.csv', header = 1)
df.head()
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0   0       1  0.85247  0.71826  0.57227        240               239
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 0          0.008064            0.000087       0.00218  ...
# 1          0.008258            0.000073       0.00195  ...
# 2          0.008340            0.000060       0.00176  ...
# 3          0.010858            0.000183       0.00419  ...
# 4          0.008162            0.002669       0.00535  ...
#
#    tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# 0                     1.5620                     2.6445
# 1                     1.5589                     3.6107
# ...

# %%
X = df.iloc[:, 1:-1] # Excluding the first and last column
X.head()
# Out:
#    gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0       1  0.85247  0.71826  0.57227        240               239
# 1       1  0.76686  0.69481  0.53966        234               233
# 2       1  0.85083  0.67604  0.58982        232               231
# 3       0  0.41121  0.79672  0.59257        178               177
# 4       0  0.32790  0.79782  0.53028        236               235
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# 0          0.008064            0.000087       0.00218      0.000018  ...
# 1          0.008258            0.000073       0.00195      0.000016  ...
# 2          0.008340            0.000060       0.00176      0.000015  ...
# 3          0.010858            0.000183       0.00419      0.000046  ...
# 4          0.008162            0.002669       0.00535      0.000044  ...
#
#    tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 0                     1.5466                     1.5620
# ...

# %%
y = df.iloc[:, -1]
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
from sklearn.linear_model import Perceptron

# %%
model = Perceptron()

# %%
model.fit(X_train, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_hat = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_hat)

print('Accuracy of Parkinson Disease Classification using Perceptron model is {}'.format(accuracy))
# Out:
# Accuracy of Parkinson Disease Classification using Perceptron model is 0.6960352422907489
